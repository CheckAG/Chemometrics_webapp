# %%
import pandas as pd
from shiny import Inputs, Outputs, Session, reactive, module, render, ui
from src.read_files import loadData

import matplotlib.pyplot as plt

# %%
main_dataframe = loadData('test_files/AS.csv')
main_dataframe
# Out:
# [array([[ 2.021     ],
#         [ 2.02959525],
#         [ 2.0381905 ],
#         ...,
#         [15.876254  ],
#         [15.883127  ],
#         [15.89      ]]),
#  array([[0.765],
#         [0.767],
#         [0.767],
#         ...,
#         [0.36 ],
#         [0.362],
#         [0.362]]),
#  'AS.csv']

# %%
plt.clf()
plt.plot(main_dataframe[0], main_dataframe[1])
plt.legend()
plt.title('RAW ADC Spectra')
plt.xlabel('Wavelength in micrometer')
# Out:
# C:\Users\flyin\AppData\Local\Temp\ipykernel_28136\1859508502.py:3: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Text(0.5, 0, 'Wavelength in micrometer')
